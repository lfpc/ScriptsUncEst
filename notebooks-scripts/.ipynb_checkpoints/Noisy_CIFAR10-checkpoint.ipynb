# %% [markdown]
# # Libs and pre-definitions

# %% [markdown]
# ### Bibliotecas padrões python e utils pytorch

# %%
import torch
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import torchvision
from torch import nn
from torch.utils.data import DataLoader, Subset
from torchvision import datasets
import torchvision.transforms as transforms
from torchvision.transforms import ToTensor, Lambda, Compose, Normalize
from collections import defaultdict
from torch.utils.data import random_split
import copy

# %%
# Define o computador utilizado como cuda (gpu) se existir ou cpu caso contrário
print(torch.cuda.is_available())
dev = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
# Out:
# True

# %% [markdown]
# ### Bibliotecas desenvolvidas
#
# https://github.com/lfpc/Uncertainty_Estimation

# %%
import NN_models as models
from NN_models import vgg
import uncertainty.comparison as unc_comp
import uncertainty.quantifications as unc
import uncertainty.losses as losses
import uncertainty.train_and_eval_with_g as TE_g
import NN_utils as utils
import NN_utils.train_and_eval as TE
import NN_utils.cifar_def as pre_data
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Data download and transforms

# %%
transforms_train = transforms.Compose([
                    transforms.ToTensor(),
                    transforms.RandomCrop(32, padding=4),
                    transforms.RandomHorizontalFlip(),
                    transforms.RandomRotation(15),
                    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])
transforms_test = transforms.Compose([
transforms.ToTensor(),
transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),])

complete_train_dataset = datasets.CIFAR10(
root="data",
 train=True,
 download=True,
transform=transforms_train)

test_data = datasets.CIFAR10(
root="data",
train=False,
download=True,
transform=transforms_test)

test_dataloader = DataLoader(test_data, batch_size = 10)

def dataloader_from_idx(complete_train_dataset,idx, batch_size = 100, train = True):
    dataset = Subset(complete_train_dataset,idx)
    if not train:
        dataset = copy.deepcopy(dataset)
        dataset.dataset.transform =transforms.Compose([
                                            transforms.ToTensor(),
                                            transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),])
    dataloader = DataLoader(dataset,batch_size = batch_size, shuffle = train)
    return dataloader
N = 5000
labeled_idx = list(range(N))
train_dataloader = dataloader_from_idx(complete_train_dataset,labeled_idx, 50)
validation_idx = list(range(45000,len(complete_train_dataset)))

                
validation_dataloader = dataloader_from_idx(complete_train_dataset,validation_idx, train = False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def model_acc_and_loss(model,loss_criterion,data):
    '''Calculate the average loss and the accuracy over a dataset.'''
    dev = next(model.parameters()).device
    running_loss = 0
    total = 0
    correct= 0
    for image,label in data:
        image,label = image.to(dev), label.to(dev)
        output = model(image)
        loss = loss_criterion(output,label)
        running_loss += loss.item()
        total += label.size(0)
        correct += TE.correct_total(output,label) 
    loss = running_loss/len(data)
    acc = (correct*100/total)
    return acc,loss

# %%
#train_dataloader, validation_dataloader, test_dataloader = pre_data.get_dataloaders()

# %%
PATH = r'/home/luis-felipe/Uncertainty_Estimation/torch_models'
PATH_trainer = r'/home/luis-felipe/Uncertainty_Estimation/torch_models/trainer'

# %% [markdown]
# # Train classifier

# %%
loss_criterion = nn.NLLLoss()
risk_dict = None#{'selective_risk_mcp':  lambda x,label: unc_comp.selective_risk(x,label,unc_type = unc.MCP_unc)}

# %%
N = 5000
labeled_idx = list(range(N))
train_dataloader = dataloader_from_idx(complete_train_dataset,labeled_idx, 50)

model = models.vgg.VGG_16(10).to(dev)
optimizer = torch.optim.SGD(model.parameters(), lr=0.1,momentum = 0.9,weight_decay = 5e-4,nesterov = True)
loss_criterion = nn.NLLLoss()

model_trainer = TE.Trainer(model,optimizer,loss_criterion, train_dataloader,validation_dataloader,c=1.0,update_lr = (100,2))
model_trainer.fit(train_dataloader,1000)

acc = TE.model_acc(model,train_dataloader)
print('Conjunto de treinamento: acc = ', acc)
acc = TE.model_acc(model,test_dataloader)
print('Conjunto de teste: acc = ', acc)
# Out:
# ...
# Conjunto de treinamento: acc =  100.0
# Conjunto de teste: acc =  79.39

# %%
N = 15000
labeled_idx = list(range(N))
train_dataloader = dataloader_from_idx(complete_train_dataset,labeled_idx, 50)

model_2 = models.vgg.VGG_16(10).to(dev)
optimizer = torch.optim.SGD(model_2.parameters(), lr=0.1,momentum = 0.9,weight_decay = 5e-4,nesterov = True)
loss_criterion = nn.NLLLoss()

model_trainer_2 = TE.Trainer(model_2,optimizer,loss_criterion, train_dataloader,validation_dataloader,c=1.0,update_lr = (100,2))
model_trainer_2.fit(train_dataloader,1000)

acc = TE.model_acc(model_2,train_dataloader)
print('Conjunto de treinamento: acc = ', acc)
acc = TE.model_acc(model_2,test_dataloader)
print('Conjunto de teste: acc = ', acc)

# %%
N = 40000
labeled_idx = list(range(N))
train_dataloader = dataloader_from_idx(complete_train_dataset,labeled_idx, 50)

model_3 = models.vgg.VGG_16(10).to(dev)
optimizer = torch.optim.SGD(model_3.parameters(), lr=0.1,momentum = 0.9,weight_decay = 5e-4,nesterov = True)
loss_criterion = nn.NLLLoss()

model_trainer_3 = TE.Trainer(model_3,optimizer,loss_criterion, train_dataloader,validation_dataloader,c=1.0,update_lr = (100,2))
model_trainer_3.fit(train_dataloader,1000 - model_trainer_3.epoch)

acc = TE.model_acc(model_3,train_dataloader)
print('Conjunto de treinamento: acc = ', acc)
acc = TE.model_acc(model_3,test_dataloader)
print('Conjunto de teste: acc = ', acc)

# %%
model = models.Model_CNN(10).cuda()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1,momentum = 0.9,weight_decay = 5e-4, nesterov = True)

model_trainer = TE.Trainer(model,optimizer,loss_criterion, train_dataloader,validation_dataloader,c=0.8,update_lr = (25,2),risk_dict = risk_dict)
model_trainer.fit(train_dataloader,500)
#model_trainer.save_all(PATH, PATH_trainer)

acc = TE.model_acc(model,train_dataloader)
print('Conjunto de treinamento: acc = ', acc)
acc = TE.model_acc(model,test_dataloader)
print('Conjunto de teste: acc = ', acc)
# Out:
# Epoch  1 , loss =  1.996295876801014
# Epoch  2 , loss =  1.7274656129831618
# Epoch  3 , loss =  1.64391677826643
# Epoch  4 , loss =  1.5866997753354637
# Epoch  5 , loss =  1.5512174588035454
# Epoch  6 , loss =  1.551196565343575
# Epoch  7 , loss =  1.5208354551683774
# Epoch  8 , loss =  1.4697660573504188
# Epoch  9 , loss =  1.441330847415057
# Epoch  10 , loss =  1.4367775998332284
# Epoch  11 , loss =  1.426947990601713
# Epoch  12 , loss =  1.4201478043740445
# Epoch  13 , loss =  1.389167776500637
# Epoch  14 , loss =  1.4166798009113832
# Epoch  15 , loss =  1.3896966210820458
# Epoch  16 , loss =  1.3747970627790147
# Epoch  17 , loss =  1.3780146105722948
# Epoch  18 , loss =  1.3666341050781987
# Epoch  19 , loss =  1.3468340723352
# Epoch  20 , loss =  1.3743063848127017
# Epoch  21 , loss =  1.3396507603201
# Epoch  22 , loss =  1.3412944891236045
# Epoch  23 , loss =  1.3264259753579444
# Epoch  24 , loss =  1.3260634595697576
# ...

# %%
model_3 = models.Model_CNN(10).cuda()
optimizer = torch.optim.SGD(model_3.parameters(), lr=0.001,momentum = 0.9) #sem momentum ficou ruim

model_trainer_3 = TE.Trainer(model_3,optimizer,loss_criterion, train_dataloader,validation_dataloader,c=0.8,risk_dict = risk_dict)
model_trainer_3.fit(train_dataloader,500)

acc = TE.model_acc(model_3,train_dataloader)
print('Conjunto de treinamento: acc = ', acc)
acc = TE.model_acc(model_3,test_dataloader)
print('Conjunto de teste: acc = ', acc)
# Out:
# Epoch  1 , loss =  2.1602925336496397
# Epoch  2 , loss =  1.9619576511057941
# Epoch  3 , loss =  1.829259136522358
# Epoch  4 , loss =  1.7335444858128375
# Epoch  5 , loss =  1.6656637472862548
# Epoch  6 , loss =  1.6126379597593437
# Epoch  7 , loss =  1.563833414492282
# Epoch  8 , loss =  1.526754871349443
# Epoch  9 , loss =  1.4974374788051301
# Epoch  10 , loss =  1.4730002216317437
# Epoch  11 , loss =  1.4469856199893085
# Epoch  12 , loss =  1.4264705397865989
# Epoch  13 , loss =  1.4053386967967858
# Epoch  14 , loss =  1.3885966095734725
# Epoch  15 , loss =  1.369218928570097
# Epoch  16 , loss =  1.354698571291837
# Epoch  17 , loss =  1.336678130721504
# Epoch  18 , loss =  1.3164415102113376
# Epoch  19 , loss =  1.3040137697349896
# Epoch  20 , loss =  1.2860591343858025
# Epoch  21 , loss =  1.271094675599174
# Epoch  22 , loss =  1.263165307315913
# Epoch  23 , loss =  1.2484342591329054
# Epoch  24 , loss =  1.2318733434446834
# ...

# %%
model_4 = models.Model_CNN(10).cuda()
optimizer = torch.optim.SGD(model_4.parameters(), lr=0.1)

model_trainer_4 = TE.Trainer(model_4,optimizer,loss_criterion, train_dataloader,validation_dataloader,c=0.8,update_lr = (25,2),risk_dict = risk_dict)
model_trainer_4.fit(train_dataloader,500)
#model_trainer.save_all(PATH, PATH_trainer)

acc = TE.model_acc(model_4,train_dataloader)
print('Conjunto de treinamento: acc = ', acc)
acc = TE.model_acc(model_4,test_dataloader)
print('Conjunto de teste: acc = ', acc)
# Out:
# Epoch  1 , loss =  1.8847165961157193
# Epoch  2 , loss =  1.6153045838529414
# Epoch  3 , loss =  1.5008467022668233
# Epoch  4 , loss =  1.411664798178456
# Epoch  5 , loss =  1.3402346176179973
# Epoch  6 , loss =  1.282878602431579
# Epoch  7 , loss =  1.2368600319393657
# Epoch  8 , loss =  1.1910603095523336
# Epoch  9 , loss =  1.1570172316648744
# Epoch  10 , loss =  1.1298546594652263
# Epoch  11 , loss =  1.0977365723387762
# Epoch  12 , loss =  1.0710396297614684
# Epoch  13 , loss =  1.0520335711877455
# Epoch  14 , loss =  1.0278423391282558
# Epoch  15 , loss =  1.009557903828946
# Epoch  16 , loss =  0.9914632607251406
# Epoch  17 , loss =  0.9789556954056025
# Epoch  18 , loss =  0.9605637050487779
# Epoch  19 , loss =  0.947548314251683
# Epoch  20 , loss =  0.9374118897725235
# Epoch  21 , loss =  0.9213395609774373
# Epoch  22 , loss =  0.909379065206105
# Epoch  23 , loss =  0.9039837255735289
# Epoch  24 , loss =  0.8928440709344365
# ...

# %%
model_2 = models.Model_CNN(10).cuda()
optimizer = torch.optim.SGD(model_2.parameters(), lr=0.001,momentum = 0.9,weight_decay = 5e-4, nesterov = True)

model_trainer_2 = TE.Trainer(model_2,optimizer,loss_criterion, train_dataloader,validation_dataloader,c=0.8,risk_dict = risk_dict)
model_trainer_2.fit(train_dataloader,500)
#esse foi o melhor

acc = TE.model_acc(model_2,train_dataloader)
print('Conjunto de treinamento: acc = ', acc)
acc = TE.model_acc(model_2,test_dataloader)
print('Conjunto de teste: acc = ', acc)
# Out:
# Epoch  1 , loss =  2.1815544082359835
# Epoch  2 , loss =  1.9461523521352897
# Epoch  3 , loss =  1.7867587249387393
# Epoch  4 , loss =  1.688627823848616
# Epoch  5 , loss =  1.6226148866117
# Epoch  6 , loss =  1.5727485428479584
# Epoch  7 , loss =  1.5276320214298638
# Epoch  8 , loss =  1.4891768456860022
# Epoch  9 , loss =  1.453105789693919
# Epoch  10 , loss =  1.4258990433405747
# Epoch  11 , loss =  1.402863040905107
# Epoch  12 , loss =  1.3802101446146315
# Epoch  13 , loss =  1.3599565615030853
# Epoch  14 , loss =  1.342161836610599
# Epoch  15 , loss =  1.3236271014267749
# Epoch  16 , loss =  1.3069309009747072
# Epoch  17 , loss =  1.288536369123242
# Epoch  18 , loss =  1.2777979417958043
# Epoch  19 , loss =  1.2654817874797366
# Epoch  20 , loss =  1.245379395105622
# Epoch  21 , loss =  1.2336602315983989
# Epoch  22 , loss =  1.2226224052296444
# Epoch  23 , loss =  1.2066776848990808
# Epoch  24 , loss =  1.1999599317258054
# ...

# %%
model_5 = models.Model_CNN(10).cuda()
optimizer = torch.optim.SGD(model_5.parameters(), lr=0.001,momentum = 0.9,weight_decay = 5e-4)

model_trainer_5 = TE.Trainer(model_5,optimizer,loss_criterion, train_dataloader,validation_dataloader,c=0.8,risk_dict = risk_dict)
model_trainer_5.fit(train_dataloader,500)
state_dict  = model_5.state_dict()

acc = TE.model_acc(model_5,train_dataloader)
print('Conjunto de treinamento: acc = ', acc)
acc = TE.model_acc(model_5,test_dataloader)
print('Conjunto de teste: acc = ', acc)
# Out:
# Epoch  1 , loss =  2.2123054431920703
# Epoch  2 , loss =  1.9585359089753844
# Epoch  3 , loss =  1.8076672604815527
# Epoch  4 , loss =  1.6855493252250282
# Epoch  5 , loss =  1.6064193861728364
# Epoch  6 , loss =  1.5624745667658069
# Epoch  7 , loss =  1.5278346342119304
# Epoch  8 , loss =  1.49951927668669
# Epoch  9 , loss =  1.4708098870786754
# Epoch  10 , loss =  1.4471165192398159
# Epoch  11 , loss =  1.4252442595633594
# Epoch  12 , loss =  1.4057169969786296
# Epoch  13 , loss =  1.382145386527885
# Epoch  14 , loss =  1.3664606264369055
# Epoch  15 , loss =  1.342634966088967
# Epoch  16 , loss =  1.3331236399032853
# Epoch  17 , loss =  1.3159276192838496
# Epoch  18 , loss =  1.2969165275042707
# Epoch  19 , loss =  1.283349049192938
# Epoch  20 , loss =  1.2735917486927726
# Epoch  21 , loss =  1.2564194889908487
# Epoch  22 , loss =  1.2445822581648827
# Epoch  23 , loss =  1.232061786746437
# Epoch  24 , loss =  1.2183996933427723
# ...
